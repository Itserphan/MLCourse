# %%
import numpy as np
import matplotlib.pyplot as plt

values = np.random.normal(0, 0.5, 10000)
plt.hist(values, 100)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
np.percentile(values, 99.999)
# Out:
# 2.0391336747225393

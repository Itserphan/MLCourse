# %% [markdown]
# import pandas as pd
# resault = pd.read_csv('pokemon_data.csv')
# resault.head()

# %%
import numpy as np
import matplotlib.pyplot as plt
numbers = np.random.normal(100.0, 20.0, 10000)
plt.hist(numbers, 100)
plt.show()

# %%
numbers.std()
# Out:
# 20.024448178638703

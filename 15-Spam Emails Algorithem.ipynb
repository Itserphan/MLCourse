# %%
import os
import io
import numpy as np
from pandas import DataFrame
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB


def readFiles(path):
    for root,dirnames,filenames in os.walk(path):
        for filename in filenames:
            path = os.path.join(root, filename)
            
            in_body= False
            lines = []
            f = io.open(path, 'r', encoding = 'latin1')
            for line in f:
                if in_body:
                    lines.append(line)
                elif line == '\n':
                    in_body = True
            f.close()
            message = '\n'.join(lines)
            yield path, message

def dataFrameFromDirectory(path, classification):
    rows = []
    index = []
    
    for file_name, message in readFiles(path):
        rows.append({'message':message, 'class':classification})
        index.append(file_name)
    
    return DataFrame(rows, index=index)



#class => Spam/NotSpam
data = DataFrame({'message':[], 'class':[]})
data = data._append(dataFrameFromDirectory('C:\TopLearnML\emails\spam','spam'))
data = data._append(dataFrameFromDirectory('C:\TopLearnML\emails\not_spam', 'not_spam'))

data.head(10)
# Out:
#                                                                                               message  \
# C:\TopLearnML\emails\spam\00001.7848dde101aa985...  <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.0 Tr...
# C:\TopLearnML\emails\spam\00002.d94f1b97e48ed3b...  1) Fight The Risk of Cancer!\n\nhttp://www.adc...
# C:\TopLearnML\emails\spam\00003.2ee33bc6eacdb11...  1) Fight The Risk of Cancer!\n\nhttp://www.adc...
# C:\TopLearnML\emails\spam\00004.eac8de8d759b7e7...  ##############################################...
# C:\TopLearnML\emails\spam\00005.57696a39d7d8431...  I thought you might like these:\n\n1) Slim Dow...
# C:\TopLearnML\emails\spam\00006.5ab5620d3d7c6c0...  A POWERHOUSE GIFTING PROGRAM You Don't Want To...
# C:\TopLearnML\emails\spam\00007.d8521faf753ff9e...  Help wanted.  We are a 14 year old fortune 500...
# C:\TopLearnML\emails\spam\00008.dfd941deb10f5ee...  <html>\n\n<head>\n\n<title>ReliaQuote - Save U...
# C:\TopLearnML\emails\spam\00009.027bf6e0b0c4ab3...  TIRED OF THE BULL OUT THERE?\n\nWant To Stop L...
# C:\TopLearnML\emails\spam\00010.445affef4c70fee...  Dear ricardo1 ,\n\n\n\n<html>\n\n<body>\n\n<ce...
#
#                                                    class
# C:\TopLearnML\emails\spam\00001.7848dde101aa985...  spam
# C:\TopLearnML\emails\spam\00002.d94f1b97e48ed3b...  spam
# C:\TopLearnML\emails\spam\00003.2ee33bc6eacdb11...  spam
# C:\TopLearnML\emails\spam\00004.eac8de8d759b7e7...  spam
# C:\TopLearnML\emails\spam\00005.57696a39d7d8431...  spam
# C:\TopLearnML\emails\spam\00006.5ab5620d3d7c6c0...  spam
# C:\TopLearnML\emails\spam\00007.d8521faf753ff9e...  spam
# C:\TopLearnML\emails\spam\00008.dfd941deb10f5ee...  spam
# C:\TopLearnML\emails\spam\00009.027bf6e0b0c4ab3...  spam
# C:\TopLearnML\emails\spam\00010.445affef4c70fee...  spam

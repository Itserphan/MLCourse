# %%
import numpy as np
import matplotlib.pyplot as plt

values = np.random.normal(0, 0.5, 10000)
plt.hist(values, 50)
# Out:
# (array([  2.,   0.,   2.,   3.,   3.,   6.,   6.,  11.,  19.,  43.,  48.,
#          72.,  88., 123., 159., 190., 256., 307., 371., 422., 464., 519.,
#         593., 582., 599., 617., 596., 585., 556., 448., 442., 419., 315.,
#         249., 205., 171., 142., 106.,  74.,  62.,  42.,  24.,  16.,  15.,
#           9.,   7.,   7.,   1.,   2.,   2.]),
#  array([-1.92722271, -1.85065163, -1.77408054, -1.69750945, -1.62093837,
#         -1.54436728, -1.4677962 , -1.39122511, -1.31465402, -1.23808294,
#         -1.16151185, -1.08494076, -1.00836968, -0.93179859, -0.85522751,
#         -0.77865642, -0.70208533, -0.62551425, -0.54894316, -0.47237207,
#         -0.39580099, -0.3192299 , -0.24265882, -0.16608773, -0.08951664,
#         -0.01294556,  0.06362553,  0.14019662,  0.2167677 ,  0.29333879,
#          0.36990987,  0.44648096,  0.52305205,  0.59962313,  0.67619422,
#          0.75276531,  0.82933639,  0.90590748,  0.98247857,  1.05904965,
#          1.13562074,  1.21219182,  1.28876291,  1.365334  ,  1.44190508,
#          1.51847617,  1.59504726,  1.67161834,  1.74818943,  1.82476051,
#          1.9013316 ]),
#  <BarContainer object of 50 artists>)

# %%
np.mean(values)
# Out:
# 0.002762284167712704

# %%
np.var(values)
# Out:
# 0.24956108664269622

# %%
import scipy.stats as sp

sp.skew(values)
# Out:
# 0.049060526738261334

# %%
import scipy.stats as sp

sp.kurtosis(values)
# Out:
# 0.049060526738261334
